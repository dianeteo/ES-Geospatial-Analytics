# %%
# Installing necessary packages
# !pip install earthengine-api
# !pip install rasterio
# !pip install google-colab
# !pip install pyarrow
# !pip install folium
# !pip install pyproj
# Out:
# WARNING: Package(s) not found: earthengine-api

# %%
import ee
import rasterio
import pandas as pd
import numpy as np
import os

# %%
ee.Authenticate(force=True)
ee.Initialize(project='mse-uhi')
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=IWQkrgphgjbR8gGWcU7aR9a-Mb5r9qC_nOxLVbqY60k&tc=N-0K3wAQFEQ7a_MEzCdNKW-EhXL2tHUQcK2mT2WJpf8&cc=2GfDbN-XnFlkiHiDGuaQRFTRinpWcwJKK_WKHe4I1Pw>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=IWQkrgphgjbR8gGWcU7aR9a-Mb5r9qC_nOxLVbqY60k&tc=N-0K3wAQFEQ7a_MEzCdNKW-EhXL2tHUQcK2mT2WJpf8&cc=2GfDbN-XnFlkiHiDGuaQRFTRinpWcwJKK_WKHe4I1Pw</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %% [markdown]
# Extracting Image Data (Singapore)

# %%
# LANDSAT 7
# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

# Load the Landsat 5 Collection 2 Tier 1 Level 2 Image Collection
Landsat5_collection = ee.ImageCollection("LANDSAT/LE07/C02/T1_L2")

# Years with 0 images: 2002, 2012

years = ['2017', '2018', '2019', '2020', '2021', '2022']
# ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
#  , '2006', '2007', '2008', '2009', '2010', '2011']
# ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
#, '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011']

for year in years:
    # Filter by date and location for a specific year
    filtered_collection = Landsat5_collection.filterDate(f'{year}-01-01', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Processing year: {year}, Images found: {image_list.size().getInfo()}")

    if image_list.size().getInfo() > 0:
        def export_each(image):
            # Format date for file naming
            date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

            # Select bands, assuming we need all available bands
            image_selected = image.toFloat()  # Convert to float if needed for processing

            # Export each image to Drive
            task = ee.batch.Export.image.toDrive(
                image=image_selected,
                description=f'L7_UTC_{date_time}',
                folder='L7_Data',
                scale=30,
                region=singapore.getInfo()['coordinates'],
                fileFormat='GeoTIFF'
            )
            task.start()
            print(f"Task {task.id} started for {date_time}. Checking status...")

            # Check and print the status of the task
            while task.active():
                task_status = task.status()
                if task_status['state'] == 'COMPLETED':
                    print(f"Task {task.id} for {date_time} completed successfully.")
                    break
                elif task_status['state'] == 'FAILED':
                    print(f"Task {task.id} for {date_time} failed with error: {task_status['error_message']}")
                    break

        # Apply the function to each image in the collection
        for i in range(image_list.size().getInfo()):
            image = ee.Image(image_list.get(i))
            export_each(image)
    else:
        print(f"No images found for the year {year}.")
# Out:
# Processing year: 2017, Images found: 18
# Task MYIKM4U2EMPDQZMJ6SF2H5PZ started for 20170105_031853. Checking status...
# Task 2SOALAHBF4IVOWUYOGT2ZSZ5 started for 20170121_031842. Checking status...
# Task 2SOALAHBF4IVOWUYOGT2ZSZ5 for 20170121_031842 completed successfully.
# Task PWGEQ7JAK47SJCVESHGKBZX5 started for 20170206_031836. Checking status...
# Task EO4PSGJG4EWENBQO74LQQOMV started for 20170222_031839. Checking status...
# Task EO4PSGJG4EWENBQO74LQQOMV for 20170222_031839 completed successfully.
# Task 2RV2LTCFF2EA6JZ77X6PWYY4 started for 20170310_031846. Checking status...
# Task NLSXKUBKVCLY27IPCK5MMKMJ started for 20170326_031851. Checking status...
# Task E5J3ADACJBBIMMDD6QNUFAXD started for 20170411_031856. Checking status...
# Task E5J3ADACJBBIMMDD6QNUFAXD for 20170411_031856 completed successfully.
# Task VTSV7XCGS2W5B4IQOQIPN2XH started for 20170427_031903. Checking status...
# Task VTSV7XCGS2W5B4IQOQIPN2XH for 20170427_031903 completed successfully.
# Task 7MH6IKPPATIMTNZPRCN2R5PX started for 20170513_031907. Checking status...
# Task 7MH6IKPPATIMTNZPRCN2R5PX for 20170513_031907 completed successfully.
# Task MMIDR5S5JCIPHCA2K7ZHIYFA started for 20170529_031910. Checking status...
# Task MMIDR5S5JCIPHCA2K7ZHIYFA for 20170529_031910 completed successfully.
# Task ICICIBDVI62FBP7L3SCMBKW5 started for 20170614_031914. Checking status...
# Task ICICIBDVI62FBP7L3SCMBKW5 for 20170614_031914 completed successfully.
# Task INSMQHBDQ6WSQCLYGJVMRSJD started for 20170630_031917. Checking status...
# Task YWWTPZLDDZZDOOWMWX3SJVUL started for 20170716_031917. Checking status...
# Task N66QRCJW5SOMS3HGNMWVR4HH started for 20170801_031916. Checking status...
# Task M4L64KCVERQ7EV7GYE6BNHUO started for 20170902_031914. Checking status...
# Task YXRG4Z5UZURRXPG6SXR5C2FB started for 20171020_031916. Checking status...
# Task YXRG4Z5UZURRXPG6SXR5C2FB for 20171020_031916 completed successfully.
# Task B23OFP7VSU3XG3IS7MVGNS3T started for 20171105_031915. Checking status...
# Task 4Q5R64QEGKVKI2AROMBSVWNO started for 20171223_031854. Checking status...
# Task 4Q5R64QEGKVKI2AROMBSVWNO for 20171223_031854 completed successfully.
# Processing year: 2018, Images found: 20
# Task 2PTBCL2J5NNOLODKEUR4HMZQ started for 20180108_031842. Checking status...
# Task LA77I522GPZQ5VWJL4EFA3PC started for 20180124_031827. Checking status...
# Task OQQ4VWASOF3EIVXBHJI7RHHA started for 20180209_031812. Checking status...
# Task ZWXSRZJWT633EYN3GNEH3Q3M started for 20180225_031803. Checking status...
# Task ZIGTL7RRMQU6R6A43PTHGDH7 started for 20180329_031738. Checking status...
# Task ZIGTL7RRMQU6R6A43PTHGDH7 for 20180329_031738 completed successfully.
# Task V3NBXTCV3AW3ZIZO7PGDAHMA started for 20180414_031723. Checking status...
# Task V3NBXTCV3AW3ZIZO7PGDAHMA for 20180414_031723 completed successfully.
# Task KW6DF4ZLYDGMGIELHY5VNRIE started for 20180430_031706. Checking status...
# Task KW6DF4ZLYDGMGIELHY5VNRIE for 20180430_031706 completed successfully.
# Task FQLF7KG273ZGID5BDJ5K3YFA started for 20180516_031650. Checking status...
# Task JXWGCPAXHVSC7CKXXQVPJYBX started for 20180617_031618. Checking status...
# Task JXWGCPAXHVSC7CKXXQVPJYBX for 20180617_031618 completed successfully.
# Task JPT6UV3R6Y7J7IUOVFJW4W3L started for 20180703_031559. Checking status...
# Task JPT6UV3R6Y7J7IUOVFJW4W3L for 20180703_031559 completed successfully.
# Task 42NEBMELA2MKSX3YH7ZI4JGP started for 20180719_031541. Checking status...
# Task QP2REY35XDD75S27BDKCJIBE started for 20180804_031524. Checking status...
# Task ORGG62OI62V6SNJRAYVCNKDI started for 20180820_031506. Checking status...
# Task W3AG76NEJZLKCEVSJCKHUXH6 started for 20180905_031446. Checking status...
# Task LWYC3LVFZ277AWXZPI2XPBDR started for 20180921_031425. Checking status...
# Task TQ5FKOUEY2MWHMBZ5XLBVFZ6 started for 20181007_031402. Checking status...
# Task TQ5FKOUEY2MWHMBZ5XLBVFZ6 for 20181007_031402 completed successfully.
# Task SQ5DYUJNACUMBFBIGA7527CZ started for 20181023_031339. Checking status...
# Task TH7ASI54Y4XNOPVQJXHMN5GP started for 20181108_031318. Checking status...
# Task LLULONRDIEQS6NCL4ZVBXTJK started for 20181210_031230. Checking status...
# Task C3QI47BEQQSKPY6GMCG62H77 started for 20181226_031202. Checking status...
# Processing year: 2019, Images found: 21
# Task EFOMSE4JAPKL7BRETXVAWFNQ started for 20190111_031133. Checking status...
# Task OU7DWU6PXBWZSDP64ECRTWJ2 started for 20190127_031101. Checking status...
# Task OU7DWU6PXBWZSDP64ECRTWJ2 for 20190127_031101 completed successfully.
# Task LTGSPF6MX6M3THEAF6C4A44M started for 20190212_031033. Checking status...
# Task LTGSPF6MX6M3THEAF6C4A44M for 20190212_031033 completed successfully.
# Task 2NGDEIW443AS2REDUDSAYHKJ started for 20190316_030933. Checking status...
# Task 2NGDEIW443AS2REDUDSAYHKJ for 20190316_030933 completed successfully.
# Task CQGJBCR4TQKHQV6N2REKZXZK started for 20190401_030900. Checking status...
# Task QMZ44NKMACSO7GQG5MGUPSXD started for 20190417_030826. Checking status...
# Task IWR7B3MNAQDR7XZN3YV2RGDL started for 20190503_030750. Checking status...
# Task CJ7DMX6OCCN4NBDWYG5AZEJS started for 20190519_030713. Checking status...
# Task L4LW5DTDJPSXNFKW76WV23OL started for 20190604_030638. Checking status...
# Task L4LW5DTDJPSXNFKW76WV23OL for 20190604_030638 completed successfully.
# Task ZLVYFE5UX4OMM2HQTP7NCLEF started for 20190620_030604. Checking status...
# Task ZLVYFE5UX4OMM2HQTP7NCLEF for 20190620_030604 completed successfully.
# Task HOPHXMGSJ3TDRMG2NHZXTK5I started for 20190706_030527. Checking status...
# Task XHNI6ORFAFIZKFBHESRCHI3Q started for 20190722_030450. Checking status...
# Task XHNI6ORFAFIZKFBHESRCHI3Q for 20190722_030450 completed successfully.
# Task TOINIM76TMQG5UE7SPQRKL5W started for 20190807_030411. Checking status...
# Task P3OAMREA5LGRE4DGLIN6UNO6 started for 20190823_030330. Checking status...
# Task YRS5CTR3ZGHDYDTRDDQAMFSM started for 20190908_030249. Checking status...
# Task YRS5CTR3ZGHDYDTRDDQAMFSM for 20190908_030249 completed successfully.
# Task YNCIFTNDXC7DCWYEH7TVHQIJ started for 20190924_030206. Checking status...
# Task YNCIFTNDXC7DCWYEH7TVHQIJ for 20190924_030206 completed successfully.
# Task RI2XNCOHD2NXGIQ5BYQGZABQ started for 20191010_030127. Checking status...
# Task A2J72SZXWSDBTHD5GHV3L7I7 started for 20191026_030046. Checking status...
# Task USM3ZHII5FJ4X66RPY4UEZWT started for 20191111_030003. Checking status...
# Task USM3ZHII5FJ4X66RPY4UEZWT for 20191111_030003 completed successfully.
# Task U2GHWRAQBCVJTUQJPK2G6HG2 started for 20191127_025917. Checking status...
# Task U2GHWRAQBCVJTUQJPK2G6HG2 for 20191127_025917 completed successfully.
# Task LC7QNU6UHL7HGKVGYAVX7XIA started for 20191229_025741. Checking status...
# Processing year: 2020, Images found: 16
# Task LXGKQVIDNQ6UF3GPIYR5HKFJ started for 20200114_025652. Checking status...
# Task QFALDGAHCNTLNUQ43ZWC2C42 started for 20200130_025604. Checking status...
# Task QFALDGAHCNTLNUQ43ZWC2C42 for 20200130_025604 completed successfully.
# Task O2DVPSCQ4EK4P3XUF4NIIE6X started for 20200215_025515. Checking status...
# Task Y7W3SERY5PRS5BSLQC75FWAE started for 20200302_025424. Checking status...
# Task Y7W3SERY5PRS5BSLQC75FWAE for 20200302_025424 completed successfully.
# Task 2CJIYJ76I4GEQ666PZAYYMM5 started for 20200318_025332. Checking status...
# Task 2CJIYJ76I4GEQ666PZAYYMM5 for 20200318_025332 completed successfully.
# Task QQLO445HMTFDUBEOCZSNDLHI started for 20200403_025238. Checking status...
# Task QQLO445HMTFDUBEOCZSNDLHI for 20200403_025238 completed successfully.
# Task 7NNSZWSL4V5KEELT2KFI2Q2Q started for 20200419_025142. Checking status...
# Task 7NNSZWSL4V5KEELT2KFI2Q2Q for 20200419_025142 completed successfully.
# Task WJAL7F5VFQAPMAGEDB7M5B2V started for 20200505_025045. Checking status...
# Task L7BFL5P5QTMGAES5VJIMVS34 started for 20200521_024946. Checking status...
# Task QY43ANT7AURQZ6KJFBRUOAOH started for 20200724_024557. Checking status...
# Task QY43ANT7AURQZ6KJFBRUOAOH for 20200724_024557 completed successfully.
# Task ICYR5TSMFUAGLOXIPJF7OEUR started for 20200809_024457. Checking status...
# Task WZE5WFLL7KRRVJQGM47JTHV2 started for 20200825_024355. Checking status...
# Task NGXSRIVQ6SMQUPRCXJDWKCKR started for 20200910_024252. Checking status...
# Task NGXSRIVQ6SMQUPRCXJDWKCKR for 20200910_024252 completed successfully.
# Task RSE7UWZGLR7OGZKFGWTTFZR7 started for 20201028_023945. Checking status...
# Task M666CC5I5I64NSIKTQKQVKUD started for 20201113_023840. Checking status...
# Task M666CC5I5I64NSIKTQKQVKUD for 20201113_023840 completed successfully.
# Task 3VUP24DS4SHX6OIHI6RHGAL2 started for 20201215_023620. Checking status...
# Processing year: 2021, Images found: 18
# Task OQ3LGHWXNM6GAZXTOUPBBVNB started for 20210116_023403. Checking status...
# Task OQ3LGHWXNM6GAZXTOUPBBVNB for 20210116_023403 completed successfully.
# Task 6MC74XQ4JRH42YWEFLL7BV6L started for 20210217_023142. Checking status...
# Task 6MC74XQ4JRH42YWEFLL7BV6L for 20210217_023142 completed successfully.
# Task QQ37U3XPHRWTTXNIU3TVR3D7 started for 20210305_023028. Checking status...
# Task QQ37U3XPHRWTTXNIU3TVR3D7 for 20210305_023028 completed successfully.
# Task QWMHF5QKBGEGIKHDJ2LDRSHW started for 20210321_022912. Checking status...
# Task QWMHF5QKBGEGIKHDJ2LDRSHW for 20210321_022912 completed successfully.
# Task UL3253W4UN35MFWAVJOG5ZS6 started for 20210406_022754. Checking status...
# Task UL3253W4UN35MFWAVJOG5ZS6 for 20210406_022754 completed successfully.
# Task SWAL3UQE7PFS4KKAZULVPJK6 started for 20210422_022633. Checking status...
# Task SWAL3UQE7PFS4KKAZULVPJK6 for 20210422_022633 completed successfully.
# Task EHJIAVJSVF7O6HLDSKCWCJ6E started for 20210508_022513. Checking status...
# Task LJSPJKN5MVH36IDH6YBDWDYX started for 20210524_022352. Checking status...
# Task GPM7D7DPRIFQJNIW76OXSMXC started for 20210609_022231. Checking status...
# Task Y3PYNBLTLPQE473EKLRCAQ4H started for 20210625_022112. Checking status...
# Task Y3PYNBLTLPQE473EKLRCAQ4H for 20210625_022112 completed successfully.
# Task HV3ONZKXDZ5XROT2YYEL6UBA started for 20210727_021829. Checking status...
# Task SAS2JB4C4OHBUSZQJDTVCQHI started for 20210812_021704. Checking status...
# Task P6Q7KF4W5JPSKPM7YKGBCHP3 started for 20210828_021540. Checking status...
# Task P6Q7KF4W5JPSKPM7YKGBCHP3 for 20210828_021540 completed successfully.
# Task I5EUY6R7FJLGMSABRKX2C6KF started for 20210929_021250. Checking status...
# Task 6CGS4IZENCPCY6375B6VXORN started for 20211015_021126. Checking status...
# Task E6YYMQMZOQZMPNOAHRXJDRDF started for 20211031_020958. Checking status...
# Task E6YYMQMZOQZMPNOAHRXJDRDF for 20211031_020958 completed successfully.
# Task CH3VAPUDTNFY5JH3AAD2PRMJ started for 20211116_020826. Checking status...
# Task TDOMXMPHRTFNCGDDE4NY7YV6 started for 20211218_020523. Checking status...
# Processing year: 2022, Images found: 17
# Task QRX7J2WZZCCUHWEMVHXF4V4W started for 20220204_020041. Checking status...
# Task IFMW6F7ZKJHWRDNNDFUJ7W2D started for 20220220_015904. Checking status...
# Task K5KY3JTFXBMXZIEVOA3IQARU started for 20220308_015731. Checking status...
# Task K5KY3JTFXBMXZIEVOA3IQARU for 20220308_015731 completed successfully.
# Task YLUEKTZWTA3KUYWEOBL3NK5S started for 20220324_015557. Checking status...
# Task YA33BQUDBEIXWBTVNLLZAAOQ started for 20220522_014715. Checking status...
# Task SZG47NRTIXQ4FMCP56PF6C22 started for 20220608_014623. Checking status...
# Task SZG47NRTIXQ4FMCP56PF6C22 for 20220608_014623 completed successfully.
# Task VOMNMY6KUXRUEIBVONIGHNOM started for 20220712_014412. Checking status...
# Task MSP2H6GRHZPVDYREJZJ74FBA started for 20220729_014253. Checking status...
# Task MSP2H6GRHZPVDYREJZJ74FBA for 20220729_014253 completed successfully.
# Task Q6JMHB66YR2NTF6PJJGJRA6I started for 20220815_014126. Checking status...
# Task N2IHMGGR2VK4SUS4QALXUPW5 started for 20220901_013952. Checking status...
# Task N2IHMGGR2VK4SUS4QALXUPW5 for 20220901_013952 completed successfully.
# Task L2XA3PWDD6XELPXTFXYBM4QV started for 20221022_013410. Checking status...
# Task 2JLCKWLDKXPHS6TBY63E6L2E started for 20221108_013155. Checking status...
# Task OQHHWWTUSRIFGWK2MQNF4FGG started for 20221217_013154. Checking status...
# Task HGQN27Z345ZCAW5MPTKHFJTX started for 20220527_015249. Checking status...
# Task HGQN27Z345ZCAW5MPTKHFJTX for 20220527_015249 completed successfully.
# Task RT4VB3IMLWRHA34QM2DEMFAS started for 20220717_014939. Checking status...
# Task ZFHY7XSGAEPCHLCZ4WYCZ6DI started for 20221027_013920. Checking status...
# Task ZFHY7XSGAEPCHLCZ4WYCZ6DI for 20221027_013920 completed successfully.
# Task B2MCG444CUYOXYAZ6FEB3OUY started for 20221113_013700. Checking status...

# %%
# LANDSAT 5
# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

# Load the Landsat 5 Collection 2 Tier 1 Level 2 Image Collection
Landsat5_collection = ee.ImageCollection("LANDSAT/LT05/C02/T1_L2")

# Years with 0 images: 2002, 2012

years = ['1989']
#, '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011']

for year in years:
    # Filter by date and location for a specific year
    filtered_collection = Landsat5_collection.filterDate(f'{year}-08-13', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Processing year: {year}, Images found: {image_list.size().getInfo()}")

    if image_list.size().getInfo() > 0:
        def export_each(image):
            # Format date for file naming
            date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

            # Select bands, assuming we need all available bands
            image_selected = image.toFloat()  # Convert to float if needed for processing

            # Export each image to Drive
            task = ee.batch.Export.image.toDrive(
                image=image_selected,
                description=f'L5_UTC_{date_time}',
                folder='L5_Data',
                scale=30,
                region=singapore.getInfo()['coordinates'],
                fileFormat='GeoTIFF'
            )
            task.start()
            print(f"Task {task.id} started for {date_time}. Checking status...")

            # Check and print the status of the task
            while task.active():
                task_status = task.status()
                if task_status['state'] == 'COMPLETED':
                    print(f"Task {task.id} for {date_time} completed successfully.")
                    break
                elif task_status['state'] == 'FAILED':
                    print(f"Task {task.id} for {date_time} failed with error: {task_status['error_message']}")
                    break

        # Apply the function to each image in the collection
        for i in range(image_list.size().getInfo()):
            image = ee.Image(image_list.get(i))
            export_each(image)
    else:
        print(f"No images found for the year {year}.")
# Out:
# Processing year: 1989, Images found: 5
# Task OQYRLKXGLMXQYHHTT7RDALMH started for 19890828_024305. Checking status...
# Task ZY4SNQHEZOEO7ZLXJI25A4EW started for 19890913_024233. Checking status...
# Task LGOYNLRHHCVDYYKIFQTGO27X started for 19890929_024221. Checking status...
# Task TJ7RQUHPCEJPLNOYO6HDTWR3 started for 19891015_024147. Checking status...
# Task FVGBQMSIEQE4HQ4Y3DXUL63W started for 19891031_024121. Checking status...
# Task FVGBQMSIEQE4HQ4Y3DXUL63W for 19891031_024121 completed successfully.

# %%
# LANDSAT 8 IMAGE
# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

# Load the Landsat 5 Collection 2 Tier 1 Level 2 Image Collection
Landsat5_collection = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")

# Years with 0 images: 2002, 2012

years = ['2024']
#, '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011']

for year in years:
    # Filter by date and location for a specific year
    filtered_collection = Landsat5_collection.filterDate(f'{year}-05-09', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Processing year: {year}, Images found: {image_list.size().getInfo()}")

    if image_list.size().getInfo() > 0:
        def export_each(image):
            # Format date for file naming
            date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

            # Select bands, assuming we need all available bands
            image_selected = image.toFloat()  # Convert to float if needed for processing

            # Export each image to Drive
            task = ee.batch.Export.image.toDrive(
                image=image_selected,
                description=f'L5_UTC_{date_time}',
                folder='L8_Data',
                scale=30,
                region=singapore.getInfo()['coordinates'],
                fileFormat='GeoTIFF'
            )
            task.start()
            print(f"Task {task.id} started for {date_time}. Checking status...")

            # Check and print the status of the task
            while task.active():
                task_status = task.status()
                if task_status['state'] == 'COMPLETED':
                    print(f"Task {task.id} for {date_time} completed successfully.")
                    break
                elif task_status['state'] == 'FAILED':
                    print(f"Task {task.id} for {date_time} failed with error: {task_status['error_message']}")
                    break

        # Apply the function to each image in the collection
        for i in range(image_list.size().getInfo()):
            image = ee.Image(image_list.get(i))
            export_each(image)
    else:
        print(f"No images found for the year {year}.")
# Out:
# Processing year: 2024, Images found: 1
# Task PDL7U5EBMGB4PZ6L6OXNW34J started for 20240609_031543. Checking status...
# Task PDL7U5EBMGB4PZ6L6OXNW34J for 20240609_031543 completed successfully.

# %%
# LANDSAT 8 IMAGE
# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

# Load the Landsat 5 Collection 2 Tier 1 Level 2 Image Collection
Landsat5_collection = ee.ImageCollection("LANDSAT/LC09/C02/T1_L2")

# Years with 0 images: 2002, 2012

years = ['2024']
#, '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011']

for year in years:
    # Filter by date and location for a specific year
    filtered_collection = Landsat5_collection.filterDate(f'{year}-05-17', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Processing year: {year}, Images found: {image_list.size().getInfo()}")

    if image_list.size().getInfo() > 0:
        def export_each(image):
            # Format date for file naming
            date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

            # Select bands, assuming we need all available bands
            image_selected = image.toFloat()  # Convert to float if needed for processing

            # Export each image to Drive
            task = ee.batch.Export.image.toDrive(
                image=image_selected,
                description=f'L5_UTC_{date_time}',
                folder='L9_Data',
                scale=30,
                region=singapore.getInfo()['coordinates'],
                fileFormat='GeoTIFF'
            )
            task.start()
            print(f"Task {task.id} started for {date_time}. Checking status...")

            # Check and print the status of the task
            while task.active():
                task_status = task.status()
                if task_status['state'] == 'COMPLETED':
                    print(f"Task {task.id} for {date_time} completed successfully.")
                    break
                elif task_status['state'] == 'FAILED':
                    print(f"Task {task.id} for {date_time} failed with error: {task_status['error_message']}")
                    break

        # Apply the function to each image in the collection
        for i in range(image_list.size().getInfo()):
            image = ee.Image(image_list.get(i))
            export_each(image)
    else:
        print(f"No images found for the year {year}.")
# Out:
# Processing year: 2024, Images found: 1
# Task 7EKJ5ILEXEARRBPCYE4AMBMM started for 20240617_031549. Checking status...
# Task 7EKJ5ILEXEARRBPCYE4AMBMM for 20240617_031549 completed successfully.

# %%
# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

# Load the Landsat 8 Collection 2 Tier 2 Image Collection
Landsat8_collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_L2')

year = "2024"

# Filter by date and location for a specific year
filtered_collection = Landsat8_collection.filterDate(f'{year}-01-01', f'{year}-12-31').filterBounds(singapore)

image_list = filtered_collection.toList(filtered_collection.size())
print(image_list.size().getInfo())

def export_each(image):
    # Format date for file naming
    date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()
    
    # Select bands, assuming we need all available bands
    image_selected = image.toFloat()  # Convert to float if needed for processing

    # Export each image to Drive
    task = ee.batch.Export.image.toDrive(
        image=image_selected,
        description=f'L8_UTC_{date_time}',
        folder=f'L8_Data/{year}',
        scale=30,
        region=singapore.getInfo()['coordinates'],
        fileFormat='GeoTIFF'
    )
    task.start()
    print(f"Task {task.id} started for {date_time}. Checking status...")

    # Check and print the status of the task
    while task.active():
        task_status = task.status()
        print(f"Task {task.id} for {date_time}: {task_status['state']}")
        if task_status['state'] == 'COMPLETED':
            print(f"Task {task.id} for {date_time} completed successfully.")
            break
        elif task_status['state'] == 'FAILED':
            print(f"Task {task.id} for {date_time} failed with error: {task_status['error_message']}")
            break

# Apply the function to each image in the collection
# for i in range(image_list.size().getInfo()):
#     image = ee.Image(image_list.get(i))
#     export_each(image)
# Out:
# 22

# %%
data_directory = f"C:\\LocalOneDrive\\Documents\\Desktop\\MTI\\UHI-Project\\MSE-ES-UHI\\Data\\Landsat8\\test_data"

# Loop through each file in the directory
for filename in os.listdir(data_directory):
    prefix = f"L8_UTC_{year}"
    if filename.startswith(prefix):
        file_path = os.path.join(data_directory, filename)

        # Open the GeoTIFF file
        with rasterio.open(file_path) as src:
            array = src.read()
            nodata_values = src.nodatavals
            band_names = src.descriptions

            # Reshape the array to a 2D array where each row is a pixel
            reshaped_array = array.transpose(1, 2, 0).reshape(-1, len(band_names))
            bands_df = pd.DataFrame(reshaped_array, columns=band_names)
            bands_df['x'] = np.tile(np.arange(src.width), src.height)
            bands_df['y'] = np.repeat(np.arange(src.height), src.width)
            bands_df['ST_B10_Celsius'] = bands_df['ST_B10'] * 0.00341802 + 149 - 273.15
            
            # Scaling and offsetting specific bands
            bands_to_scale = ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7']
            for band in bands_to_scale:
                bands_df[f"{band}_Scaled"] = bands_df[band] * 2.75e-05 - 0.2

            additional_scales = {
                'ST_ATRAN': 0.0001, 'ST_CDIST': 0.01, 'ST_DRAD': 0.001, 
                'ST_EMIS': 0.0001, 'ST_EMSD': 0.0001, 'ST_QA': 0.01, 
                'ST_TRAD': 0.001, 'ST_URAD': 0.001
            }
            for band, scale in additional_scales.items():
                bands_df[f"{band}_Scaled"] = bands_df[band] * scale

            # Replace NoData values appropriately
            for i, nodata_value in enumerate(nodata_values):
                if nodata_value is not None:
                    bands_df.iloc[:, i].replace(nodata_value, np.nan, inplace=True)

            # Save the bands data to CSV
            bands_csv_path = os.path.join(data_directory, f'Landsat8_Bands_{filename[-19:-4]}.csv')
            bands_df.to_csv(bands_csv_path, index=False)

            print(f"Saved band data to {bands_csv_path}") 

            # Extract and save metadata to CSV
            metadata = src.meta
            metadata_df = pd.DataFrame([metadata])
            metadata_csv_path = os.path.join(data_directory, f'Landsat8_Metadata_{filename[-19:-4]}.csv')
            metadata_df.to_csv(metadata_csv_path, index=False)

            print(f"Saved metadata to {metadata_csv_path}")
# Out:
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220111_031652.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220111_031652.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220127_031646.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220127_031646.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220212_031643.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220212_031643.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220228_031639.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220228_031639.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220316_031633.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220316_031633.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220401_031622.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220401_031622.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220417_031628.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220417_031628.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220503_031626.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220503_031626.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220519_031634.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220519_031634.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220604_031640.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220604_031640.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220706_031652.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220706_031652.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220722_031656.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220722_031656.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220807_031706.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220807_031706.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220823_031710.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220823_031710.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20220924_031717.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20220924_031717.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20221111_031713.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20221111_031713.csv
# Saved band data to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Bands_20221127_031711.csv
# Saved metadata to C:\LocalOneDrive\Documents\Desktop\MTI\UHI-Project\MSE-ES-UHI\Data\Landsat8\2022\Landsat8_Metadata_20221127_031711.csv

# %% [markdown]
# ### Saving metadata

# %%
# LANDSAT 5

# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

# Load the Landsat 9 Collection 2 Tier 1 Level 2 Image Collection (correcting collection ID)
Landsat5_collection = ee.ImageCollection("LANDSAT/LT05/C02/T1_L2")

year = "2024"

# Filter by date and location for a specific year
filtered_collection = Landsat5_collection.filterDate(f'{year}-01-01', f'{year}-12-31').filterBounds(singapore)

image_list = filtered_collection.toList(filtered_collection.size())
print(f"Number of images found: {image_list.size().getInfo()}")

def export_each(image):
    # Format date for file naming
    date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()
    
    # Select bands, assuming we need all available bands
    image_selected = image.toFloat()  # Convert to float if needed for processing

    # Export each image to Drive
    task = ee.batch.Export.image.toDrive(
        image=image_selected,
        description=f'L9_UTC_{date_time}',
        folder=f'L9_Data/{year}',
        scale=30,
        region=singapore.getInfo()['coordinates'],
        fileFormat='GeoTIFF'
    )
    task.start()
    print(f"Image export task {task.id} started for {date_time}.")

    # Export the associated metadata as a JSON file
    metadata_task = ee.batch.Export.table.toDrive(
        collection=ee.FeatureCollection([ee.Feature(None, image.toDictionary())]),
        description=f'L9_Metadata_{date_time}',
        folder=f'L9_Data/{year}',
        fileFormat='CSV'
    )
    metadata_task.start()
    print(f"Metadata export task {metadata_task.id} started for {date_time}.")

    # Check and print the status of the tasks
    while task.active() or metadata_task.active():
        if task.active():
            task_status = task.status()
            print(f"Image task {task.id} for {date_time}: {task_status['state']}")
            if task_status['state'] == 'COMPLETED':
                print(f"Image task {task.id} for {date_time} completed successfully.")
            elif task_status['state'] == 'FAILED':
                print(f"Image task {task.id} for {date_time} failed with error: {task_status['error_message']}")

        if metadata_task.active():
            metadata_task_status = metadata_task.status()
            print(f"Metadata task {metadata_task.id} for {date_time}: {metadata_task_status['state']}")
            if metadata_task_status['state'] == 'COMPLETED':
                print(f"Metadata task {metadata_task.id} for {date_time} completed successfully.")
            elif metadata_task_status['state'] == 'FAILED':
                print(f"Metadata task {metadata_task.id} for {date_time} failed with error: {metadata_task_status['error_message']}")

# Apply the function to each image in the collection
for i in range(image_list.size().getInfo()):
    image = ee.Image(image_list.get(i))
    export_each(image)
# Out:
# Number of images found: 9
# Image export task XOSJJILPBTCNWGPWMNI5JPZT started for 20240109_031653.
# Metadata export task HIM3RE52WRVKAAR6H4VZR5LS started for 20240109_031653.
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image task XOSJJILPBTCNWGPWMNI5JPZT for 20240109_031653: RUNNING
# Image export task SI74EHFXU64AFH44LYWZJJ6U started for 20240125_031651.
# Metadata export task UQJQWINW23SXMLAEX32YPV2S started for 20240125_031651.
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: READY
# Metadata task UQJQWINW23SXMLAEX32YPV2S for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: RUNNING
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651: COMPLETED
# Image task SI74EHFXU64AFH44LYWZJJ6U for 20240125_031651 completed successfully.
# Image export task 7H2W7BZRNIIVYQJHS5A45QVD started for 20240210_031656.
# Metadata export task KTXUTVCCTQ2MEOZDMOFH2EHS started for 20240210_031656.
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: READY
# Metadata task KTXUTVCCTQ2MEOZDMOFH2EHS for 20240210_031656: READY
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Metadata task KTXUTVCCTQ2MEOZDMOFH2EHS for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: RUNNING
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656: COMPLETED
# Image task 7H2W7BZRNIIVYQJHS5A45QVD for 20240210_031656 completed successfully.
# Image export task L7HTRNWCYHXEDTHJINPQDDWC started for 20240226_031644.
# Metadata export task CSRGSTYOL4T57J6CLVXBL4MC started for 20240226_031644.
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: READY
# Metadata task CSRGSTYOL4T57J6CLVXBL4MC for 20240226_031644: READY
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: READY
# Metadata task CSRGSTYOL4T57J6CLVXBL4MC for 20240226_031644: READY
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Metadata task CSRGSTYOL4T57J6CLVXBL4MC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: RUNNING
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644: COMPLETED
# Image task L7HTRNWCYHXEDTHJINPQDDWC for 20240226_031644 completed successfully.
# Image export task IT4PTZKDDL3NS7SYLCJQ5WJ7 started for 20240313_031647.
# Metadata export task FV4MUT2R2JRKVXHK2WTTA2T4 started for 20240313_031647.
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: READY
# Metadata task FV4MUT2R2JRKVXHK2WTTA2T4 for 20240313_031647: READY
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Metadata task FV4MUT2R2JRKVXHK2WTTA2T4 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image task IT4PTZKDDL3NS7SYLCJQ5WJ7 for 20240313_031647: RUNNING
# Image export task OECDQTXYXHNUJFP224R4PRCR started for 20240329_031638.
# Metadata export task Y43IXZBR42ERLQIZTCJNX4QB started for 20240329_031638.
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Metadata task Y43IXZBR42ERLQIZTCJNX4QB for 20240329_031638: READY
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Metadata task Y43IXZBR42ERLQIZTCJNX4QB for 20240329_031638: READY
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Metadata task Y43IXZBR42ERLQIZTCJNX4QB for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Metadata task Y43IXZBR42ERLQIZTCJNX4QB for 20240329_031638: COMPLETED
# Metadata task Y43IXZBR42ERLQIZTCJNX4QB for 20240329_031638 completed successfully.
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# Image task OECDQTXYXHNUJFP224R4PRCR for 20240329_031638: RUNNING
# ...
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image task S2UCW47CTDZCIP657O5SVRFR for 20240516_031607: RUNNING
# Image export task KHSZVAXUHPBKNC5TYZ2WBKOJ started for 20240617_031549.
# Metadata export task Z6JA4DOWOFPHFB2SJTJ2W6GZ started for 20240617_031549.
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: READY
# Metadata task Z6JA4DOWOFPHFB2SJTJ2W6GZ for 20240617_031549: READY
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: READY
# Metadata task Z6JA4DOWOFPHFB2SJTJ2W6GZ for 20240617_031549: READY
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: READY
# Metadata task Z6JA4DOWOFPHFB2SJTJ2W6GZ for 20240617_031549: READY
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: READY
# Metadata task Z6JA4DOWOFPHFB2SJTJ2W6GZ for 20240617_031549: READY
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: READY
# Metadata task Z6JA4DOWOFPHFB2SJTJ2W6GZ for 20240617_031549: READY
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: READY
# Metadata task Z6JA4DOWOFPHFB2SJTJ2W6GZ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING
# Image task KHSZVAXUHPBKNC5TYZ2WBKOJ for 20240617_031549: RUNNING

# %%
# LANDSAT 5
# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

def export_metadata_for_year(year):
    # Access the Landsat 5 Collection
    Landsat5_collection = ee.ImageCollection("LANDSAT/LT05/C02/T1_L2")

    # Filter images by date and location for the specific year
    filtered_collection = Landsat5_collection.filterDate(f'{year}-01-01', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Number of images scheduled for metadata export in {year}: {image_list.size().getInfo()}")

    for i in range(image_list.size().getInfo()):
        image = ee.Image(image_list.get(i))
        date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

        # Export metadata as a CSV file
        metadata_task = ee.batch.Export.table.toDrive(
            collection=ee.FeatureCollection([ee.Feature(None, image.toDictionary())]),
            description=f'L5_Metadata_{date_time}',
            folder=f'L5_Metadata',
            fileFormat='CSV'
        )

        metadata_task.start()
        print(f"Started metadata export task for: {date_time}")

# Export metadata for each year in the specified range
for year in range(1990, 2012):
    if year == 2002:
        continue
    export_metadata_for_year(year)
# Out:
# Number of images scheduled for metadata export in 1990: 14
# Started metadata export task for: 19900103_023927
# Started metadata export task for: 19900220_023759
# Started metadata export task for: 19900308_023724
# Started metadata export task for: 19900409_023646
# Started metadata export task for: 19900511_023652
# Started metadata export task for: 19900527_023648
# Started metadata export task for: 19900612_023648
# Started metadata export task for: 19900628_023647
# Started metadata export task for: 19900714_023644
# Started metadata export task for: 19900730_023640
# Started metadata export task for: 19900831_023629
# Started metadata export task for: 19900916_023628
# Started metadata export task for: 19901018_023610
# Started metadata export task for: 19901103_023602
# Number of images scheduled for metadata export in 1991: 11
# Started metadata export task for: 19910311_023756
# Started metadata export task for: 19910327_023812
# Started metadata export task for: 19910412_023829
# Started metadata export task for: 19910428_023845
# Started metadata export task for: 19910530_023917
# Started metadata export task for: 19910615_023926
# Started metadata export task for: 19910818_024010
# Started metadata export task for: 19910903_024023
# Started metadata export task for: 19910919_024034
# Started metadata export task for: 19911005_024037
# Started metadata export task for: 19911021_024047
# Number of images scheduled for metadata export in 1992: 10
# Started metadata export task for: 19920125_024055
# Started metadata export task for: 19920210_024048
# Started metadata export task for: 19920313_024047
# Started metadata export task for: 19920703_023947
# Started metadata export task for: 19920719_023935
# Started metadata export task for: 19920820_023906
# Started metadata export task for: 19920921_023837
# Started metadata export task for: 19921007_023812
# Started metadata export task for: 19921023_023804
# Started metadata export task for: 19921226_023802
# Number of images scheduled for metadata export in 1993: 11
# Started metadata export task for: 19930111_023813
# Started metadata export task for: 19930401_023851
# Started metadata export task for: 19930503_023904
# Started metadata export task for: 19930519_023907
# Started metadata export task for: 19930604_023911
# Started metadata export task for: 19930908_023859
# Started metadata export task for: 19930924_023855
# Started metadata export task for: 19931026_023845
# Started metadata export task for: 19931111_023837
# Started metadata export task for: 19931127_023832
# Started metadata export task for: 19931213_023826
# Number of images scheduled for metadata export in 1994: 18
# Started metadata export task for: 19940114_023802
# Started metadata export task for: 19940130_023751
# Started metadata export task for: 19940319_023711
# Started metadata export task for: 19940404_023655
# Started metadata export task for: 19940506_023619
# Started metadata export task for: 19940522_023602
# Started metadata export task for: 19940607_023544
# Started metadata export task for: 19940623_023522
# Started metadata export task for: 19940709_023457
# Started metadata export task for: 19940810_023404
# Started metadata export task for: 19940826_023341
# Started metadata export task for: 19940911_023317
# Started metadata export task for: 19940927_023251
# Started metadata export task for: 19941013_023222
# Started metadata export task for: 19941029_023149
# Started metadata export task for: 19941114_023115
# Started metadata export task for: 19941130_023044
# Started metadata export task for: 19941216_023015
# Number of images scheduled for metadata export in 1995: 12
# Started metadata export task for: 19950117_022908
# Started metadata export task for: 19950322_022634
# Started metadata export task for: 19950423_022514
# Started metadata export task for: 19950509_022431
# Started metadata export task for: 19950525_022348
# Started metadata export task for: 19950610_022302
# Started metadata export task for: 19950626_022220
# Started metadata export task for: 19950712_022136
# Started metadata export task for: 19950728_022053
# Started metadata export task for: 19950813_022009
# Started metadata export task for: 19950829_021925
# Started metadata export task for: 19950930_021749
# Number of images scheduled for metadata export in 1996: 18
# Started metadata export task for: 19960120_022015
# Started metadata export task for: 19960221_022227
# Started metadata export task for: 19960308_022331
# Started metadata export task for: 19960324_022433
# Started metadata export task for: 19960409_022533
# Started metadata export task for: 19960425_022632
# Started metadata export task for: 19960511_022728
# Started metadata export task for: 19960527_022823
# Started metadata export task for: 19960628_023007
# Started metadata export task for: 19960714_023057
# Started metadata export task for: 19960730_023148
# Started metadata export task for: 19960831_023331
# Started metadata export task for: 19960916_023424
# Started metadata export task for: 19961018_023605
# Started metadata export task for: 19961103_023651
# Started metadata export task for: 19961119_023736
# Started metadata export task for: 19961205_023822
# Started metadata export task for: 19961221_023907
# Number of images scheduled for metadata export in 1997: 13
# Started metadata export task for: 19970106_023953
# Started metadata export task for: 19970122_024038
# Started metadata export task for: 19970207_024120
# Started metadata export task for: 19970311_024239
# Started metadata export task for: 19970327_024315
# Started metadata export task for: 19970514_024456
# Started metadata export task for: 19970530_024531
# Started metadata export task for: 19970615_024603
# Started metadata export task for: 19970802_024742
# Started metadata export task for: 19970818_024812
# Started metadata export task for: 19970903_024841
# Started metadata export task for: 19971005_024936
# Started metadata export task for: 19971021_025002
# Number of images scheduled for metadata export in 1998: 19
# Started metadata export task for: 19980109_025159
# Started metadata export task for: 19980125_025219
# Started metadata export task for: 19980210_025240
# Started metadata export task for: 19980226_025257
# Started metadata export task for: 19980314_025312
# Started metadata export task for: 19980330_025324
# Started metadata export task for: 19980415_025336
# Started metadata export task for: 19980501_025348
# Started metadata export task for: 19980517_025405
# Started metadata export task for: 19980602_025421
# Started metadata export task for: 19980704_025445
# Started metadata export task for: 19980805_025459
# Started metadata export task for: 19980821_025509
# Started metadata export task for: 19980922_025527
# Started metadata export task for: 19981008_025528
# Started metadata export task for: 19981024_025528
# Started metadata export task for: 19981109_025537
# Started metadata export task for: 19981125_025539
# Started metadata export task for: 19981211_025535
# Number of images scheduled for metadata export in 1999: 20
# Started metadata export task for: 19990112_025538
# Started metadata export task for: 19990128_025540
# Started metadata export task for: 19990301_025550
# Started metadata export task for: 19990317_025537
# Started metadata export task for: 19990402_025520
# Started metadata export task for: 19990418_025522
# Started metadata export task for: 19990504_025518
# Started metadata export task for: 19990520_025459
# Started metadata export task for: 19990605_025440
# Started metadata export task for: 19990621_025432
# Started metadata export task for: 19990723_025421
# Started metadata export task for: 19990808_025418
# Started metadata export task for: 19990824_025404
# Started metadata export task for: 19990909_025330
# Started metadata export task for: 19990925_025308
# Started metadata export task for: 19991011_025315
# Started metadata export task for: 19991027_025301
# Started metadata export task for: 19991112_025228
# Started metadata export task for: 19991214_025146
# Started metadata export task for: 19991230_025143
# Number of images scheduled for metadata export in 2000: 19
# Started metadata export task for: 20000115_025132
# Started metadata export task for: 20000216_025030
# Started metadata export task for: 20000303_024955
# Started metadata export task for: 20000319_025034
# Started metadata export task for: 20000404_025102
# Started metadata export task for: 20000420_025129
# Started metadata export task for: 20000506_025212
# Started metadata export task for: 20000522_025228
# Started metadata export task for: 20000709_025331
# Started metadata export task for: 20000725_025344
# Started metadata export task for: 20000810_025407
# Started metadata export task for: 20000826_025427
# Started metadata export task for: 20000911_025449
# Started metadata export task for: 20000927_025500
# Started metadata export task for: 20001013_025509
# Started metadata export task for: 20001029_025524
# Started metadata export task for: 20001114_025536
# Started metadata export task for: 20001130_025551
# Started metadata export task for: 20001216_025606
# Number of images scheduled for metadata export in 2001: 13
# Started metadata export task for: 20010202_025637
# Started metadata export task for: 20010218_025639
# Started metadata export task for: 20010306_025646
# Started metadata export task for: 20010322_025647
# Started metadata export task for: 20010423_025641
# Started metadata export task for: 20010509_025649
# Started metadata export task for: 20010610_025700
# Started metadata export task for: 20010626_025659
# Started metadata export task for: 20010712_025702
# Started metadata export task for: 20010728_025656
# Started metadata export task for: 20010813_025655
# Started metadata export task for: 20010829_025649
# Started metadata export task for: 20010914_025645
# Number of images scheduled for metadata export in 2003: 3
# Started metadata export task for: 20031123_025504
# Started metadata export task for: 20031209_025508
# Started metadata export task for: 20031225_025520
# Number of images scheduled for metadata export in 2004: 19
# Started metadata export task for: 20040211_025531
# Started metadata export task for: 20040227_025537
# Started metadata export task for: 20040330_025547
# Started metadata export task for: 20040415_025619
# Started metadata export task for: 20040501_025645
# Started metadata export task for: 20040517_025714
# Started metadata export task for: 20040602_025741
# Started metadata export task for: 20040618_025808
# Started metadata export task for: 20040704_025838
# Started metadata export task for: 20040720_025904
# Started metadata export task for: 20040805_025923
# Started metadata export task for: 20040906_030013
# Started metadata export task for: 20040922_030037
# Started metadata export task for: 20041008_030057
# Started metadata export task for: 20041024_030118
# Started metadata export task for: 20041109_030137
# Started metadata export task for: 20041125_030153
# Started metadata export task for: 20041211_030215
# Started metadata export task for: 20041227_030230
# Number of images scheduled for metadata export in 2005: 15
# Started metadata export task for: 20050112_030241
# Started metadata export task for: 20050128_030254
# Started metadata export task for: 20050213_030309
# Started metadata export task for: 20050317_030336
# Started metadata export task for: 20050418_030345
# Started metadata export task for: 20050504_030351
# Started metadata export task for: 20050520_030357
# Started metadata export task for: 20050605_030406
# Started metadata export task for: 20050707_030416
# Started metadata export task for: 20050723_030428
# Started metadata export task for: 20050824_030442
# Started metadata export task for: 20050909_030445
# Started metadata export task for: 20050925_030444
# Started metadata export task for: 20051011_030440
# Started metadata export task for: 20051112_030457
# Number of images scheduled for metadata export in 2006: 15
# Started metadata export task for: 20060131_030649
# Started metadata export task for: 20060216_030711
# Started metadata export task for: 20060304_030731
# Started metadata export task for: 20060405_030808
# Started metadata export task for: 20060507_030838
# Started metadata export task for: 20060523_030850
# Started metadata export task for: 20060608_030906
# Started metadata export task for: 20060624_030921
# Started metadata export task for: 20060726_030948
# Started metadata export task for: 20060811_031000
# Started metadata export task for: 20060827_031011
# Started metadata export task for: 20060912_031023
# Started metadata export task for: 20060928_031035
# Started metadata export task for: 20061030_031055
# Started metadata export task for: 20061201_031111
# Number of images scheduled for metadata export in 2007: 13
# Started metadata export task for: 20070102_031125
# Started metadata export task for: 20070203_031136
# Started metadata export task for: 20070219_031137
# Started metadata export task for: 20070307_031135
# Started metadata export task for: 20070408_031128
# Started metadata export task for: 20070510_031112
# Started metadata export task for: 20070526_031101
# Started metadata export task for: 20070611_031045
# Started metadata export task for: 20070713_031018
# Started metadata export task for: 20070729_031010
# Started metadata export task for: 20070814_031000
# Started metadata export task for: 20070915_030943
# Started metadata export task for: 20071001_030935
# Number of images scheduled for metadata export in 2008: 17
# Started metadata export task for: 20080222_030706
# Started metadata export task for: 20080309_030647
# Started metadata export task for: 20080325_030626
# Started metadata export task for: 20080410_030604
# Started metadata export task for: 20080426_030540
# Started metadata export task for: 20080512_030514
# Started metadata export task for: 20080528_030448
# Started metadata export task for: 20080629_030355
# Started metadata export task for: 20080715_030328
# Started metadata export task for: 20080731_030300
# Started metadata export task for: 20080816_030232
# Started metadata export task for: 20080901_030206
# Started metadata export task for: 20080917_030138
# Started metadata export task for: 20081019_030035
# Started metadata export task for: 20081104_030002
# Started metadata export task for: 20081206_030035
# Started metadata export task for: 20081222_030103
# Number of images scheduled for metadata export in 2009: 16
# Started metadata export task for: 20090107_030129
# Started metadata export task for: 20090123_030154
# Started metadata export task for: 20090208_030219
# Started metadata export task for: 20090312_030306
# Started metadata export task for: 20090328_030327
# Started metadata export task for: 20090413_030347
# Started metadata export task for: 20090429_030404
# Started metadata export task for: 20090515_030423
# Started metadata export task for: 20090531_030440
# Started metadata export task for: 20090803_030546
# Started metadata export task for: 20090819_030600
# Started metadata export task for: 20090904_030614
# Started metadata export task for: 20090920_030627
# Started metadata export task for: 20091022_030647
# Started metadata export task for: 20091107_030655
# Started metadata export task for: 20091209_030711
# Number of images scheduled for metadata export in 2010: 6
# Started metadata export task for: 20100126_030728
# Started metadata export task for: 20100211_030731
# Started metadata export task for: 20100331_030733
# Started metadata export task for: 20100705_030710
# Started metadata export task for: 20100806_030700
# Started metadata export task for: 20101009_030639
# Number of images scheduled for metadata export in 2011: 5
# Started metadata export task for: 20110113_030633
# Started metadata export task for: 20110214_030636
# Started metadata export task for: 20110302_030635
# Started metadata export task for: 20110318_030630
# Started metadata export task for: 20111028_030431

# %%
# LANDSAT 7

# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

def export_metadata_for_year(year):
    # Access the Landsat 5 Collection
    Landsat7_collection = ee.ImageCollection("LANDSAT/LE07/C02/T1_L2")

    # Filter images by date and location for the specific year
    filtered_collection = Landsat7_collection.filterDate(f'{year}-01-01', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Number of images scheduled for metadata export in {year}: {image_list.size().getInfo()}")

    for i in range(image_list.size().getInfo()):
        image = ee.Image(image_list.get(i))
        date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

        # Export metadata as a CSV file
        metadata_task = ee.batch.Export.table.toDrive(
            collection=ee.FeatureCollection([ee.Feature(None, image.toDictionary())]),
            description=f'L7_Metadata_{date_time}',
            folder=f'L7_Metadata',
            fileFormat='CSV'
        )

        metadata_task.start()
        print(f"Started metadata export task for: {date_time}")

# Export metadata for each year in the specified range
for year in range(2015, 2023):
    export_metadata_for_year(year)
# Out:
# Number of images scheduled for metadata export in 1999: 1
# Started metadata export task for: 19990901_030935
# Number of images scheduled for metadata export in 2000: 6
# Started metadata export task for: 20000428_030856
# Started metadata export task for: 20000530_030834
# Started metadata export task for: 20000717_030804
# Started metadata export task for: 20000903_030727
# Started metadata export task for: 20001106_030658
# Started metadata export task for: 20001208_030658
# Number of images scheduled for metadata export in 2001: 13
# Started metadata export task for: 20010109_030705
# Started metadata export task for: 20010226_030658
# Started metadata export task for: 20010314_030655
# Started metadata export task for: 20010330_030647
# Started metadata export task for: 20010415_030645
# Started metadata export task for: 20010501_030642
# Started metadata export task for: 20010517_030629
# Started metadata export task for: 20010720_030556
# Started metadata export task for: 20010906_030513
# Started metadata export task for: 20010922_030505
# Started metadata export task for: 20011024_030454
# Started metadata export task for: 20011109_030504
# Started metadata export task for: 20011125_030512
# Number of images scheduled for metadata export in 2002: 20
# Started metadata export task for: 20020112_030524
# Started metadata export task for: 20020128_030526
# Started metadata export task for: 20020301_030536
# Started metadata export task for: 20020317_030527
# Started metadata export task for: 20020402_030523
# Started metadata export task for: 20020504_030529
# Started metadata export task for: 20020520_030520
# Started metadata export task for: 20020605_030514
# Started metadata export task for: 20020621_030506
# Started metadata export task for: 20020707_030503
# Started metadata export task for: 20020723_030453
# Started metadata export task for: 20020808_030448
# Started metadata export task for: 20020824_030441
# Started metadata export task for: 20020909_030435
# Started metadata export task for: 20020925_030424
# Started metadata export task for: 20021011_030413
# Started metadata export task for: 20021027_030425
# Started metadata export task for: 20021112_030430
# Started metadata export task for: 20021214_030453
# Started metadata export task for: 20021230_030458
# Number of images scheduled for metadata export in 2003: 10
# Started metadata export task for: 20030115_030503
# Started metadata export task for: 20030304_030521
# Started metadata export task for: 20030320_030519
# Started metadata export task for: 20030405_030523
# Started metadata export task for: 20030421_030521
# Started metadata export task for: 20030507_030523
# Started metadata export task for: 20030523_030518
# Started metadata export task for: 20030827_030500
# Started metadata export task for: 20031115_030512
# Started metadata export task for: 20031201_030518
# Number of images scheduled for metadata export in 2004: 14
# Started metadata export task for: 20040102_030532
# Started metadata export task for: 20040118_030536
# Started metadata export task for: 20040219_030544
# Started metadata export task for: 20040306_030549
# Started metadata export task for: 20040322_030554
# Started metadata export task for: 20040407_030552
# Started metadata export task for: 20040423_030545
# Started metadata export task for: 20040509_030549
# Started metadata export task for: 20040525_030548
# Started metadata export task for: 20040610_030541
# Started metadata export task for: 20040712_030537
# Started metadata export task for: 20041016_030515
# Started metadata export task for: 20041117_030534
# Started metadata export task for: 20041219_030552
# Number of images scheduled for metadata export in 2005: 14
# Started metadata export task for: 20050120_030602
# Started metadata export task for: 20050205_030608
# Started metadata export task for: 20050221_030616
# Started metadata export task for: 20050309_030620
# Started metadata export task for: 20050410_030614
# Started metadata export task for: 20050426_030611
# Started metadata export task for: 20050715_030603
# Started metadata export task for: 20050816_030557
# Started metadata export task for: 20050901_030549
# Started metadata export task for: 20050917_030541
# Started metadata export task for: 20051019_030548
# Started metadata export task for: 20051120_030609
# Started metadata export task for: 20051206_030614
# Started metadata export task for: 20051222_030616
# Number of images scheduled for metadata export in 2006: 13
# Started metadata export task for: 20060208_030640
# Started metadata export task for: 20060312_030644
# Started metadata export task for: 20060413_030639
# Started metadata export task for: 20060429_030640
# Started metadata export task for: 20060515_030642
# Started metadata export task for: 20060531_030641
# Started metadata export task for: 20060616_030637
# Started metadata export task for: 20060702_030631
# Started metadata export task for: 20060718_030623
# Started metadata export task for: 20060803_030619
# Started metadata export task for: 20060920_030608
# Started metadata export task for: 20061123_030638
# Started metadata export task for: 20061225_030650
# Number of images scheduled for metadata export in 2007: 8
# Started metadata export task for: 20070110_030651
# Started metadata export task for: 20070211_030702
# Started metadata export task for: 20070416_030708
# Started metadata export task for: 20070518_030658
# Started metadata export task for: 20070603_030653
# Started metadata export task for: 20070705_030652
# Started metadata export task for: 20070907_030629
# Started metadata export task for: 20071228_030658
# Number of images scheduled for metadata export in 2008: 4
# Started metadata export task for: 20080113_030659
# Started metadata export task for: 20080520_030635
# Started metadata export task for: 20080605_030628
# Started metadata export task for: 20081011_030514
# Number of images scheduled for metadata export in 2009: 8
# Started metadata export task for: 20090216_030633
# Started metadata export task for: 20090304_030642
# Started metadata export task for: 20090320_030649
# Started metadata export task for: 20090507_030703
# Started metadata export task for: 20090523_030704
# Started metadata export task for: 20090608_030704
# Started metadata export task for: 20090624_030702
# Started metadata export task for: 20090726_030654
# Number of images scheduled for metadata export in 2010: 9
# Started metadata export task for: 20100203_030824
# Started metadata export task for: 20100219_030835
# Started metadata export task for: 20100307_030843
# Started metadata export task for: 20100408_030850
# Started metadata export task for: 20100424_030850
# Started metadata export task for: 20101017_030902
# Started metadata export task for: 20101102_030910
# Started metadata export task for: 20101118_030923
# Started metadata export task for: 20101220_030941
# Number of images scheduled for metadata export in 2011: 11
# Started metadata export task for: 20110121_030958
# Started metadata export task for: 20110222_031007
# Started metadata export task for: 20110326_031012
# Started metadata export task for: 20110427_031014
# Started metadata export task for: 20110801_031005
# Started metadata export task for: 20110817_031002
# Started metadata export task for: 20110902_030959
# Started metadata export task for: 20110918_030954
# Started metadata export task for: 20111020_030957
# Started metadata export task for: 20111105_031003
# Started metadata export task for: 20111207_031024
# Number of images scheduled for metadata export in 2012: 14
# Started metadata export task for: 20120124_031037
# Started metadata export task for: 20120209_031044
# Started metadata export task for: 20120225_031046
# Started metadata export task for: 20120328_031045
# Started metadata export task for: 20120413_031040
# Started metadata export task for: 20120429_031102
# Started metadata export task for: 20120515_031122
# Started metadata export task for: 20120616_031103
# Started metadata export task for: 20120702_031112
# Started metadata export task for: 20120904_031158
# Started metadata export task for: 20120920_031206
# Started metadata export task for: 20121006_031215
# Started metadata export task for: 20121107_031228
# Started metadata export task for: 20121123_031237
# Number of images scheduled for metadata export in 2013: 14
# Started metadata export task for: 20130126_031249
# Started metadata export task for: 20130211_031250
# Started metadata export task for: 20130227_031246
# Started metadata export task for: 20130315_031245
# Started metadata export task for: 20130416_031237
# Started metadata export task for: 20130502_031232
# Started metadata export task for: 20130518_031230
# Started metadata export task for: 20130603_031220
# Started metadata export task for: 20130619_031216
# Started metadata export task for: 20130721_031158
# Started metadata export task for: 20130822_031159
# Started metadata export task for: 20131025_031241
# Started metadata export task for: 20131212_031259
# Started metadata export task for: 20131228_031303
# Number of images scheduled for metadata export in 2014: 16
# Started metadata export task for: 20140113_031309
# Started metadata export task for: 20140129_031328
# Started metadata export task for: 20140214_031325
# Started metadata export task for: 20140302_031323
# Started metadata export task for: 20140318_031331
# Started metadata export task for: 20140403_031337
# Started metadata export task for: 20140419_031346
# Started metadata export task for: 20140622_031404
# Started metadata export task for: 20140708_031409
# Started metadata export task for: 20140724_031413
# Started metadata export task for: 20140809_031417
# Started metadata export task for: 20140825_031414
# Started metadata export task for: 20141028_031444
# Started metadata export task for: 20141113_031453
# Started metadata export task for: 20141129_031458
# Started metadata export task for: 20141215_031506
# Number of images scheduled for metadata export in 2015: 17
# Started metadata export task for: 20150116_031511
# Started metadata export task for: 20150201_031518
# Started metadata export task for: 20150217_031521
# Started metadata export task for: 20150305_031531
# Started metadata export task for: 20150321_031539
# Started metadata export task for: 20150406_031546
# Started metadata export task for: 20150422_031551
# Started metadata export task for: 20150508_031600
# Started metadata export task for: 20150524_031605
# Started metadata export task for: 20150609_031613
# Started metadata export task for: 20150727_031623
# Started metadata export task for: 20150828_031628
# Started metadata export task for: 20150913_031633
# Started metadata export task for: 20150929_031636
# Started metadata export task for: 20151015_031650
# Started metadata export task for: 20151031_031704
# Started metadata export task for: 20151218_031751
# Number of images scheduled for metadata export in 2016: 15
# Started metadata export task for: 20160307_031839
# Started metadata export task for: 20160323_031846
# Started metadata export task for: 20160408_031849
# Started metadata export task for: 20160424_031858
# Started metadata export task for: 20160510_031901
# Started metadata export task for: 20160526_031905
# Started metadata export task for: 20160713_031911
# Started metadata export task for: 20160729_031914
# Started metadata export task for: 20160814_031915
# Started metadata export task for: 20160830_031918
# Started metadata export task for: 20160915_031920
# Started metadata export task for: 20161001_031923
# Started metadata export task for: 20161118_031910
# Started metadata export task for: 20161204_031907
# Started metadata export task for: 20161220_031902
# Number of images scheduled for metadata export in 2017: 18
# Started metadata export task for: 20170105_031853
# Started metadata export task for: 20170121_031842
# Started metadata export task for: 20170206_031836
# Started metadata export task for: 20170222_031839
# Started metadata export task for: 20170310_031846
# Started metadata export task for: 20170326_031851
# Started metadata export task for: 20170411_031856
# Started metadata export task for: 20170427_031903
# Started metadata export task for: 20170513_031907
# Started metadata export task for: 20170529_031910
# Started metadata export task for: 20170614_031914
# Started metadata export task for: 20170630_031917
# Started metadata export task for: 20170716_031917
# Started metadata export task for: 20170801_031916
# Started metadata export task for: 20170902_031914
# Started metadata export task for: 20171020_031916
# Started metadata export task for: 20171105_031915
# Started metadata export task for: 20171223_031854
# Number of images scheduled for metadata export in 2018: 20
# Started metadata export task for: 20180108_031842
# Started metadata export task for: 20180124_031827
# Started metadata export task for: 20180209_031812
# Started metadata export task for: 20180225_031803
# Started metadata export task for: 20180329_031738
# Started metadata export task for: 20180414_031723
# Started metadata export task for: 20180430_031706
# Started metadata export task for: 20180516_031650
# Started metadata export task for: 20180617_031618
# Started metadata export task for: 20180703_031559
# Started metadata export task for: 20180719_031541
# Started metadata export task for: 20180804_031524
# Started metadata export task for: 20180820_031506
# Started metadata export task for: 20180905_031446
# Started metadata export task for: 20180921_031425
# Started metadata export task for: 20181007_031402
# Started metadata export task for: 20181023_031339
# Started metadata export task for: 20181108_031318
# Started metadata export task for: 20181210_031230
# Started metadata export task for: 20181226_031202
# Number of images scheduled for metadata export in 2019: 21
# Started metadata export task for: 20190111_031133
# Started metadata export task for: 20190127_031101
# Started metadata export task for: 20190212_031033
# Started metadata export task for: 20190316_030933
# Started metadata export task for: 20190401_030900
# Started metadata export task for: 20190417_030826
# Started metadata export task for: 20190503_030750
# Started metadata export task for: 20190519_030713
# Started metadata export task for: 20190604_030638
# Started metadata export task for: 20190620_030604
# Started metadata export task for: 20190706_030527
# Started metadata export task for: 20190722_030450
# Started metadata export task for: 20190807_030411
# Started metadata export task for: 20190823_030330
# Started metadata export task for: 20190908_030249
# Started metadata export task for: 20190924_030206
# Started metadata export task for: 20191010_030127
# Started metadata export task for: 20191026_030046
# Started metadata export task for: 20191111_030003
# Started metadata export task for: 20191127_025917
# Started metadata export task for: 20191229_025741
# Number of images scheduled for metadata export in 2020: 16
# Started metadata export task for: 20200114_025652
# Started metadata export task for: 20200130_025604
# Started metadata export task for: 20200215_025515
# Started metadata export task for: 20200302_025424
# Started metadata export task for: 20200318_025332
# Started metadata export task for: 20200403_025238
# Started metadata export task for: 20200419_025142
# Started metadata export task for: 20200505_025045
# Started metadata export task for: 20200521_024946
# Started metadata export task for: 20200724_024557
# Started metadata export task for: 20200809_024457
# Started metadata export task for: 20200825_024355
# Started metadata export task for: 20200910_024252
# Started metadata export task for: 20201028_023945
# Started metadata export task for: 20201113_023840
# Started metadata export task for: 20201215_023620
# Number of images scheduled for metadata export in 2021: 18
# Started metadata export task for: 20210116_023403
# Started metadata export task for: 20210217_023142
# Started metadata export task for: 20210305_023028
# Started metadata export task for: 20210321_022912
# Started metadata export task for: 20210406_022754
# Started metadata export task for: 20210422_022633
# Started metadata export task for: 20210508_022513
# Started metadata export task for: 20210524_022352
# Started metadata export task for: 20210609_022231
# Started metadata export task for: 20210625_022112
# Started metadata export task for: 20210727_021829
# Started metadata export task for: 20210812_021704
# Started metadata export task for: 20210828_021540
# Started metadata export task for: 20210929_021250
# Started metadata export task for: 20211015_021126
# Started metadata export task for: 20211031_020958
# Started metadata export task for: 20211116_020826
# Started metadata export task for: 20211218_020523
# Number of images scheduled for metadata export in 2022: 17
# Started metadata export task for: 20220204_020041
# Started metadata export task for: 20220220_015904
# Started metadata export task for: 20220308_015731
# Started metadata export task for: 20220324_015557
# Started metadata export task for: 20220522_014715
# Started metadata export task for: 20220608_014623
# Started metadata export task for: 20220712_014412
# Started metadata export task for: 20220729_014253
# Started metadata export task for: 20220815_014126
# Started metadata export task for: 20220901_013952
# Started metadata export task for: 20221022_013410
# Started metadata export task for: 20221108_013155
# Started metadata export task for: 20221217_013154
# Started metadata export task for: 20220527_015249
# Started metadata export task for: 20220717_014939
# Started metadata export task for: 20221027_013920
# Started metadata export task for: 20221113_013700

# %%
# LANDSAT 8
# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

def export_metadata_for_year(year):
    # Access the Landsat 5 Collection
    Landsat8_collection = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")

    # Filter images by date and location for the specific year
    filtered_collection = Landsat8_collection.filterDate(f'{year}-05-09', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Number of images scheduled for metadata export in {year}: {image_list.size().getInfo()}")

    for i in range(image_list.size().getInfo()):
        image = ee.Image(image_list.get(i))
        date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

        # Export metadata as a CSV file
        metadata_task = ee.batch.Export.table.toDrive(
            collection=ee.FeatureCollection([ee.Feature(None, image.toDictionary())]),
            description=f'L8_Metadata_{date_time}',
            folder=f'L8_Metadata',
            fileFormat='CSV'
        )

        metadata_task.start()
        print(f"Started metadata export task for: {date_time}")

export_metadata_for_year(2024)

# # Export metadata for each year in the specified range
# for year in range(2014, 2025):
#     export_metadata_for_year(year)
# Out:
# Number of images scheduled for metadata export in 2024: 1
# Started metadata export task for: 20240609_031543

# %%
# LANDSAT 8

# Define the region of interest
singapore = ee.Geometry.Rectangle([103.59, 1.13, 104.07, 1.47])

def export_metadata_for_year(year):
    # Access the Landsat 5 Collection
    Landsat9_collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_L2')

    # Filter images by date and location for the specific year
    filtered_collection = Landsat9_collection.filterDate(f'{year}-01-01', f'{year}-12-31').filterBounds(singapore)

    image_list = filtered_collection.toList(filtered_collection.size())
    print(f"Number of images scheduled for metadata export in {year}: {image_list.size().getInfo()}")

    for i in range(image_list.size().getInfo()):
        image = ee.Image(image_list.get(i))
        date_time = image.date().format('YYYYMMdd_HHmmss').getInfo()

        # Export metadata as a CSV file
        metadata_task = ee.batch.Export.table.toDrive(
            collection=ee.FeatureCollection([ee.Feature(None, image.toDictionary())]),
            description=f'L9_Metadata_{date_time}',
            folder=f'L9_Metadata',
            fileFormat='CSV'
        )

        metadata_task.start()
        print(f"Started metadata export task for: {date_time}")

# Export metadata for each year in the specified range
for year in range(2021, 2025):
    export_metadata_for_year(year)
# Out:
# Number of images scheduled for metadata export in 2021: 4
# Started metadata export task for: 20211031_031441
# Started metadata export task for: 20211105_031711
# Started metadata export task for: 20211110_031939
# Started metadata export task for: 20211115_032207
# Number of images scheduled for metadata export in 2022: 19
# Started metadata export task for: 20220119_031653
# Started metadata export task for: 20220204_031654
# Started metadata export task for: 20220220_031646
# Started metadata export task for: 20220308_031639
# Started metadata export task for: 20220324_031636
# Started metadata export task for: 20220409_031632
# Started metadata export task for: 20220425_031623
# Started metadata export task for: 20220527_031608
# Started metadata export task for: 20220628_031631
# Started metadata export task for: 20220714_031625
# Started metadata export task for: 20220730_031640
# Started metadata export task for: 20220815_031649
# Started metadata export task for: 20220831_031652
# Started metadata export task for: 20220916_031656
# Started metadata export task for: 20221002_031659
# Started metadata export task for: 20221018_031705
# Started metadata export task for: 20221103_031702
# Started metadata export task for: 20221205_031703
# Started metadata export task for: 20221221_031702
# Number of images scheduled for metadata export in 2023: 21
# Started metadata export task for: 20230106_031705
# Started metadata export task for: 20230122_031656
# Started metadata export task for: 20230207_031708
# Started metadata export task for: 20230223_031654
# Started metadata export task for: 20230311_031646
# Started metadata export task for: 20230327_031638
# Started metadata export task for: 20230412_031631
# Started metadata export task for: 20230428_031624
# Started metadata export task for: 20230514_031615
# Started metadata export task for: 20230530_031606
# Started metadata export task for: 20230615_031557
# Started metadata export task for: 20230701_031606
# Started metadata export task for: 20230717_031614
# Started metadata export task for: 20230802_031620
# Started metadata export task for: 20230903_031635
# Started metadata export task for: 20230919_031642
# Started metadata export task for: 20231005_031644
# Started metadata export task for: 20231021_031653
# Started metadata export task for: 20231106_031647
# Started metadata export task for: 20231208_031651
# Started metadata export task for: 20231224_031658
# Number of images scheduled for metadata export in 2024: 9
# Started metadata export task for: 20240109_031653
# Started metadata export task for: 20240125_031651
# Started metadata export task for: 20240210_031656
# Started metadata export task for: 20240226_031644
# Started metadata export task for: 20240313_031647
# Started metadata export task for: 20240329_031638
# Started metadata export task for: 20240430_031614
# Started metadata export task for: 20240516_031607
# Started metadata export task for: 20240617_031549
